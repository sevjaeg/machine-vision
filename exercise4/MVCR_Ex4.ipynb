# %% [markdown]
# # Machine Vision and Cognitive Robotics - Exercise 4
#
# <!--
# Automation and Control Institute - TU Wien
# Matthias Hirschmanner 2019
# machinevision@acin.tuwien.ac.at
#  -->

# %% [markdown]
# In this exercise you will implement a neural network to classify images of the CIFAR10 dataset (https://www.cs.toronto.edu/~kriz/cifar.html). It consists of 60000 images with a resolution of 32x32. The different classes and example images for each classes are shown in Figure 1 below. We will use the library Keras with the TensorFlow backend to create our neural networks. More specifically, we will use the Functional API of Keras.
#
#
# ![Classes of CIFAR10](https://i2.wp.com/appliedmachinelearning.blog/wp-content/uploads/2018/03/cifar2.jpg?resize=427%2C325&ssl=1)
#
# Figure 1: Examples of the different classes of the CIFAR10 dataset.
#
# ---
#
#
#
# Please keep the code in the sections below clean and only change it in the dedicated areas. You shouldn't need to change it anywhere else. You also shouldn't need to use any additional libraries other than the ones already imported. If you need to change the code somewhere else or need to import a different library to get a functioning program, that might be a bug. Please report it in the Tuwel forum or send us a mail to machinevision@acin.tuwien.ac.at

# %% [markdown]
# ## Import Libraries
# In a first step we import the libraries needed for the exercise. Please execute the cell below.

# %%
# Sets the tensorflow version. If you use conda, you might need to delete this line
import numpy as np
from matplotlib import pyplot as plt
import random
import requests
import imageio
from PIL import Image
from typing import Tuple

from tensorflow import Tensor

from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Model
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import regularizers
from tensorflow.keras import callbacks 

import tensorflow.keras.utils 
import tensorflow.keras.backend as K
from tensorflow.python.client import device_lib

# Fixes a crash when running on Mac OS
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

get_ipython().__class__.__name__ = "ZMQInteractiveShell"

print("These devices are available. If no GPU shows up in Google Colab, \
change Runtime type to GPU.")
print(device_lib.list_local_devices())
# Out:
# These devices are available. If no GPU shows up in Google Colab, change Runtime type to GPU.
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14814736472458073908
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6963513280
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3333463886559723080
# physical_device_desc: "device: 0, name: GeForce RTX 2060 SUPER, pci bus id: 0000:2b:00.0, compute capability: 7.5"
# ]

# %% [markdown]
# ## Load Dataset
# Next we load the CIFAR10 dataset. The training images are in the numpy array `X_train` and the test images in the numpy array `X_test`. The labels are contained in the numpy arrays `y_train`and `y_test`.

# %%
# Load datasetlassify images of the CI
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# Print shape of arrays:
print('Training Images Shape:', X_train.shape, 'Data Type:', X_train.dtype)
print('Test Images Shape:', X_test.shape)
print('Training Labels Shape:', y_train.shape)
print('Test Labels Shape:', y_test.shape)
# Out:
# Training Images Shape: (50000, 32, 32, 3) Data Type: uint8
# Test Images Shape: (10000, 32, 32, 3)
# Training Labels Shape: (50000, 1)
# Test Labels Shape: (10000, 1)

# %% [markdown]
# ## Plot random images

# %%
#@title Run this cell!
#@markdown It will show you 9 random images of the dataset. 
#@markdown The code itself is not relevant, but it is important for later to execute this cell because some plotting functions are defined here. 
fig, axs = plt.subplots(3, 3,figsize=(10,10))
labels = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',6:'frog',7:'horse',8:'ship',9:'truck'}
random_indices = np.random.randint(X_test.shape[0], size=9)
for (idx,ax) in zip(random_indices,axs.flat):
  ax.set_title(labels[y_test[idx,0]])
  ax.imshow(X_test[idx])
  
#Function to plot the training
def plot_history(history):

  # Plot the Training History
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,5))
  fig.suptitle('MLP Training')
  ax1.plot(history.history['accuracy'], label="Train")
  ax1.plot(history.history['val_accuracy'], label="Test")
  ax1.set(xlabel='Epoch', ylabel='Accuracy')
  ax1.legend(loc="upper left")
  ax2.plot(history.history['loss'], label='Train')
  ax2.plot(history.history['val_loss'], label='Test')
  ax2.set(xlabel='Epoch', ylabel='Loss')
  ax2.legend(loc="upper right")


#Function corect/wrong recognition:
def plot_predictions(data, model_name, class_name=None):
  labels = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',6:'frog',7:'horse',8:'ship',9:'truck'}
  labels_inv = {v: k for k, v in labels.items()}
  y_predictions = model_name.predict(data) 

  # Get the predicted labels [0,9]
  y_predictions_labels = np.argmax(y_predictions,axis=1)
  y_predictions[y_predictions<0.5]=0 # prediction rate R

# getting a list of ALL images and labels with predicion rate R 
  out_ind = np.nonzero(y_predictions) # index of non zero
  out_ind_label = out_ind[1] # index of a label 0-9
  out_ind_image = out_ind[0] # index of an image 0...N (N - size of dataset)
  out_images = X_test[out_ind_image]
# getting lists of ONLY correct and wrong predicted images
  true_out_ind = out_ind[0][y_test[out_ind[0]][:,0] == out_ind_label]
  wrong_out_ind = out_ind[0][y_test[out_ind[0]][:,0] != out_ind_label]
# check if class_name defined at all  (1.'if' if class_name defined, 2.'if' if class_name from the labels list)
  if class_name:
    class_number = labels_inv.get(class_name, -1)
    if class_number != -1: # taking only predictions with defined class_name 

      # Images that were correctly predicted with class_name
      true_out_ind = true_out_ind[y_predictions_labels[true_out_ind]==class_number]
      
      # Images that are part of class_name, but were wrongly predicted
      false_positive_ind = wrong_out_ind[y_predictions_labels[wrong_out_ind]==class_number]

      # Images that are part of class_name but were wrongly predicted
      false_negative_ind = wrong_out_ind[y_test[wrong_out_ind][:,0]==class_number]
      print('Number of correct recognized', class_name, 'images is', len(true_out_ind))
      print('Number of images recognized as', class_name, 'but are not of that class is', len(false_positive_ind))
      print('Number of images not recognized as', class_name, 'but actually are of that class is', len(false_negative_ind))

    else:
      print('No such class like', class_name + '. Check class name again.')
  else:  
    print('Number of correct recognized images is', len(true_out_ind))
    print('Number of wrong recognized images is', len(wrong_out_ind))
# plot of 10 correct and 10 wrong random recognized images 
  true_ind_plot = random.sample(list(true_out_ind), k=10) # correct
  wrong_ind_plot = random.sample(list(wrong_out_ind), k=10) # wrong
  if class_name:
    if class_number != -1:
      fig = plt.figure(figsize=(20,7.5))

      if len(false_positive_ind) > 10:
        false_positive_ind_plot = random.sample(list(false_positive_ind), k=10) # wrong
      else:
        false_positive_ind_plot = false_positive_ind
      
      if len(false_negative_ind) > 10:
        false_negative_ind_plot = random.sample(list(false_negative_ind), k=10) # wrong
      else:
        false_negative_ind_plot = false_negative_ind

      for idx, image_idx in enumerate(true_ind_plot):
        a = fig.add_subplot(3, 10, idx+1)
        imgplot = plt.imshow(X_test[image_idx])
        a.set_title(labels[y_predictions_labels[image_idx]], color='green', y=-0.2)
        a.axis('off')
      for idx, image_idx in enumerate(false_positive_ind_plot):
        a = fig.add_subplot(3, 10, idx+11)
        imgplot = plt.imshow(X_test[image_idx])
        a.set_title(labels[y_predictions_labels[image_idx]], color='red', y=-0.2)
        a.axis('off')
        a.set_xlabel(labels[y_predictions_labels[image_idx]], color='red')
      for idx, image_idx in enumerate(false_negative_ind_plot):
        a = fig.add_subplot(3, 10, idx+21)
        imgplot = plt.imshow(X_test[image_idx])
        a.set_title(labels[y_predictions_labels[image_idx]], color='red', y=-0.2)
        a.axis('off')
      plt.figtext(0.5,0.9, "Correct Predictions", ha="center", va="top", fontsize=14)
      plt.figtext(0.5,0.63, "False Positives", ha="center", va="top", fontsize=14)
      plt.figtext(0.5,0.36, "False Negatives", ha="center", va="top", fontsize=14)

  else:
    fig = plt.figure(figsize=(20,5))
    for idx, image_idx in enumerate(true_ind_plot):
      a = fig.add_subplot(2, 10, idx+1)
      imgplot = plt.imshow(X_test[image_idx])
      a.set_title(labels[y_predictions_labels[image_idx]], color='green')
    for idx, image_idx in enumerate(wrong_ind_plot):
      a = fig.add_subplot(2, 10, idx+11)
      imgplot = plt.imshow(X_test[image_idx])
      a.set_title(labels[y_predictions_labels[image_idx]], color='red')


# Normalization of an image and training
def predict_image(nn_model, image):
  labels = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',6:'frog',7:'horse',8:'ship',9:'truck'}
  # prediction with a model
  test_prediction = nn_model.predict(image) # define a model of nn
  print(test_prediction)
  # top 5 predictions
  out_ind_up = sorted(range(len(list(test_prediction[0]))), key = lambda sub: test_prediction[0][sub])[-5:] 
  # result
  print("Top-5 Predictions:")
  for i in out_ind_up[::-1]:
    print(' ', labels[i].capitalize(), '-', round((test_prediction[0][i])*100,2), '%') 
  
# Load an image from an external URL an returns it
def load_image_link(link): 
  response = requests.get(link)
  im_from_link = Image.fromarray(imageio.imread((response.content))) 
  # Adjust width and height to CIFAR10 resolution
  width = 32
  height = 32
  loaded_image = im_from_link.resize((width, height), Image.ANTIALIAS)
  loaded_image = np.expand_dims(loaded_image, axis = 0)
  return loaded_image

# Load an image from Colab folder
def load_image_colab(image_name): 
  # Default Colab folder: "/content/..."
  imageFile = "/content/" + image_name # taking a file with original size
  im_from_fold = Image.open(imageFile) # if you do it from colab folder
  # Adjust width and height to CIFAR10 resolution
  width = 32
  height = 32
  loaded_image = np.array(im_from_fold.resize((width, height), Image.ANTIALIAS))
  loaded_image = np.expand_dims(loaded_image, axis = 0)
  return loaded_image

# %% [markdown]
# ## Normalize Images (1 Point)
# Your first task is to create the function `normalize_images` which takes the training images `X_train` and the test images `X_test` as parameters. The outputs should be the two normalized sets with the shape `(dataset_size, 32, 32, 3)` and data type `np.float32`. Normalize in a way, that the returned arrays have approximately zero mean ($\mu=0$) and unit variance ($\sigma=1$). You can decide if you want to normalize per color channel or over the whole dataset. Only use the standard numpy functionality to implement this function (e.g. `np.mean()`, `np.var()`, `np.std()`, etc.)
#
# **IMPORTANT:** Use the same mean and and standard deviation you get from the training set also for the test set, because we want our training and test data to go through the same transformation.
#
# You can find more detailed explanation of why we do normalization in this video by Andrew Ng: [Andrew Ng - Normalizing Inputs](https://www.youtube.com/watch?v=FDCfw-YqWTE)

# %%
def normalize_images(training_images: np.ndarray, 
                     test_images: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
  """ Normalize training and test images to have zero mean and unit variance

  :param training_images: The training images
  :type training_images: np.ndarray with shape (train_batch_size, width, height, channels)
    and dtype = np.uint8 and values in the range [0, 255]

  :param test_images: The test images
  :type test_images: np.ndarray with shape (test_batch_size, width, height, channels)
    with dtype = np.uint8 and values in the range [0, 255]
  
  :return: (normalized_training_images, normalized_test_images)
    normalized_training_images: Normalized training images with zero mean and unit variance
  :rtype: Tuple(normalized_training_images, normalized_test_images)
    normalized_training_images: np.ndarray with shape (train_batch_size, width, height, channels)
      and dtype = np.float32
    normalized_test_images: np.ndarray with shape (test_batch_size, width, height, channels)
      and dtype = np.float32
  """
  ########## Fix This Part ##########

  print("mean before", np.mean(training_images))
  print("std before",  np.std(training_images))
  
  normalized_training_images = np.zeros(training_images.shape)
  normalized_test_images = np.zeros(test_images.shape)
  for i in range(3):  # normalise colour by colour
    mean = np.mean(training_images[:,:,:,i])
    stddev = np.std(training_images[:,:,:,i])
    normalized_training_images[:,:,:,i] = (training_images[:,:,:,i] - mean)/stddev.astype(np.float32)
    normalized_test_images[:,:,:,i] = (test_images[:,:,:,i] - mean)/stddev.astype(np.float32)
  
  print("normalised")
  print("mean after",  np.mean(normalized_training_images)) 
  print("std after",  np.std(normalized_training_images))
  ###################################

  return normalized_training_images, normalized_test_images

# %% [markdown]
# ## Preprocess labels (1 Point)
# Keras needs the labels as an one-hot encoded vector for training. The function `preprocess_labels(labels, no_of_classes)` should take a label with shape `(batch_size, 1)`, an integer with the number of classes and create a one-hot encoded numpy array with the shape `(batch_size, number_of_classes)`. Keras has the built-in function `tensorflow.keras.utils.to_categorical` which creates this vector for us. For this exercise, don't use it or similar functions.

# %%
def preprocess_labels(labels: np.ndarray, 
                      no_of_classes: int) -> np.ndarray:
  """ Return one-hot encoded labels

  :param labels: Labels for each training/test image as a number in the range [0, number_of_classes - 1]
  :type labels: np.ndarray with shape (batch_size, 1) and dtype = np.uint8

  :param no_of_classes: Number of classes in the dataset
  :type no_of_classes: int

  :return output_labels: The one-hot encoded labels. Each label is a vector with 
    all entries = 0 and a single entry = 1 at the index of the correct class. 
  :rtype: np.ndarray with shape (batch_size, 10) with dtype = np.float32
  """
  ########## Fix This Part ##########
  
  output_labels = np.zeros((labels.shape[0], no_of_classes))
  for c in range(no_of_classes):
    output_labels[np.where(labels[:,0]==c), c] = 1.0

  ###################################
  
  return output_labels

# %% [markdown]
# The next cell tests your function with the built-in function of Keras:

# %%
y_train_onehot = preprocess_labels(y_train, 10)
y_test_onehot = preprocess_labels(y_test, 10)
if((y_train_onehot == tensorflow.keras.utils.to_categorical(y_train, 10)).all() 
  and (y_test_onehot == tensorflow.keras.utils.to_categorical(y_test,10)).all()):
  print("Test Successful!")
else:
  print(y_train[(0,1,2,3),])
  print(y_train_onehot[(0,1,2,3),:])
  print(tensorflow.keras.utils.to_categorical(y_train, 10)[(0,1,2,3),:])
  print("Something went wrong, check your preprocess_labels function")
# Out:
# Test Successful!

# %% [markdown]
# ##Loss Function (1 Point)
# We need a loss function to perform the actual training of our model. Implement the cross-entropy loss with the mathematical functions defined in keras.backend. The function `my_crossentropy_loss` should take the input tensor `y_true` with the one-hot-encoded training labels and the predictions of our network `y_pred` which is a tensor of the same dimensions with the softmax prediction values for each class (between 0 and 1). The shape of the input tensors is `(number_of_predictions, number_of_classes)` and the shape of the output tensor should be `(number_of_predictions,)`. You should use the functions provided in the Keras backend e.g. `K.sum()` (https://www.tensorflow.org/api_docs/python/tf/keras/backend/sum). Don't use the built-in crossentropy loss of Keras. For an example check the code snippet below. The cross-entropy loss is defined as
# \begin{equation}
# L(\mathbf{y},\mathbf{\hat{y}})=-\sum_{k=1}^{K}y_{k}\log(\hat{y}_{k}).
# \end{equation}
#
# This video gives a good explanation about the cross-entropy loss: https://youtu.be/ueO_Ph0Pyqk

# %%
def my_crossentropy_loss(y_true: Tensor, 
                         y_pred: Tensor) -> Tensor:
  """ Calculate the categorical crossentropy loss between the labels and the prediction

  :param y_true: One-hot encoded training labels
  :type y_true: tf.Tensor with shape (batch_size, num_classes) and dtype = np.float32

  :param y_pred: Prediction values of classes in the range [0, 1]
  :type y_pred: tf.Tensor with shape (batch_size, num_classes) and dtype = np.float32

  :return: Categorical crossentropy loss
  :rtype: tf.Tensor with shape (batch_size,) and dtype = np.float32
  """
  ########## Fix This Part ##########

  loss = -K.sum(y_true * K.log(y_pred), axis=1)
  
  ###################################
  
  return loss

# %% [markdown]
# You can check your implementation by comparing it to the built-in function of Keras. In the example below we have the prediction and true_labels of 4 images with 3 classes:

# %%
label_tensor = K.constant([1., 0., 0., \
                           0., 1., 0., \
                           0., 0., 1., \
                           0., 0., 1.], shape=[4,3])

prediction_tensor = K.constant([.9,  .05, .05, \
                                .05, .89, .06, \
                                .5,  .4,  .1,  \
                                .01, .01, .98], shape=[4,3])

my_crossentropy_output = my_crossentropy_loss(label_tensor, prediction_tensor)
keras_crossentropy_output = K.categorical_crossentropy(label_tensor, prediction_tensor)

print('Input shape: ', label_tensor.shape, ' Output Shape: ', my_crossentropy_output.shape)
print('My Crossentropy Loss:    ', K.eval(my_crossentropy_output))
print('Keras built-in function: ', K.eval(keras_crossentropy_output))
# Out:
# Input shape:  (4, 3)  Output Shape:  (4,)
# My Crossentropy Loss:     [0.10536055 0.11653383 2.3025851  0.02020269]
# Keras built-in function:  [0.10536055 0.11653383 2.3025851  0.02020269]

# %% [markdown]
# ## Linear Classifier (1 Point)
# In a first Step we want to train a simple network with only one layer (no hidden layers). A dense layer takes each input value (each pixel intensity) multiplies it with a weight and adds a bias term for each output neuron. An animation of the process is shown here: https://codelabs.developers.google.com/codelabs/cloud-tensorflow-mnist/#3
#
# To be able to feed the images to the network, we need to reshape them to a vector. The function `vectorize_images(images)` takes as input parameter our images as a `numpy.array` with the shape `(batch_size, height, width, color_channels)` and returns a `numpy.array` with the shape `(batch_size, input_dim)`. You can use the function `np.reshape()`.

# %%
def vectorize_images(images: np.ndarray) -> np.ndarray:
  """ Reshape images to one-dimensional vectors

  :param images: The input images to be normalized
  :type images: np.ndarray with shape (batch_size, height, width, color_channels)

  :return: The images as one-dimensional arrays
  :rtype: np.ndarray with shape (batch_size, height * width * color_channels)
    and the same datatype as the input images
  """
  ########## Fix This Part ##########
  images_vector = np.reshape(images,
                             (images.shape[0], images.shape[1]*images.shape[2]*
                              images.shape[3]))
  print("reshaped to", images_vector.shape)
  ###################################

  return images_vector


# First normalize our training and test images
X_train_normalized, X_test_normalized = normalize_images(X_train, X_test)

# Now use vectorize_images to create our vectors
X_train_vector = vectorize_images(X_train_normalized)
X_test_vector = vectorize_images(X_test_normalized)
# Out:
# mean before 120.70756512369792
# std before 64.1500758911213
# normalised
# mean after 5.1523230126804264e-17
# std after 0.9999999981401643
# reshaped to (50000, 3072)
# reshaped to (10000, 3072)

# %% [markdown]
# To create the model please use the functional API of Keras since it is more flexible than the sequential model: https://keras.io/getting-started/functional-api-guide/
#
# In this part, you should only need to change the arguments of the functions. You can keep the general structure as it is.

# %%
########## Fix This Part ##########

# This returns a tensor
inputs = layers.Input(shape=X_train_vector.shape[1])

# A layer instance is callable on a tensor, and returns a tensor
output_layer = layers.Dense(units=10, activation="softmax")(inputs)

###################################


# This creates a model that includes
# the Input layer and one Dense layer
one_layer_model = Model(inputs=inputs,
                        outputs=output_layer)

# We compile our model with the Stochastic Gradient Descent as optimizer
# and the cross-entropy loss we implemented earlier
one_layer_model.compile(optimizer='sgd',
              loss=my_crossentropy_loss, 
              metrics=['accuracy'])

one_layer_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                30730
# =================================================================
# Total params: 30,730
# Trainable params: 30,730
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Actual Training
# This command starts the actual training. Make sure you selected the hardware accelarator GPU in Runtime -> Change Runtime type. One epoch should take below 10 seconds.
#
# Run the training for about 30 epochs which should get you to >30% validation accuracy. If the model doesn't go above ~10% (random guessing), check your normalization and the activation function of the `output_layer`.

# %%
history_one_layer=one_layer_model.fit(x=X_train_vector, 
                                      y=y_train_onehot, 
                                      validation_data=(X_test_vector, y_test_onehot), 
                                      epochs=30)  # starts training
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 6s 3ms/step - loss: 2.1163 - accuracy: 0.3009 - val_loss: 1.9420 - val_accuracy: 0.3508
# Epoch 2/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.9157 - accuracy: 0.3619 - val_loss: 1.8792 - val_accuracy: 0.3656
# Epoch 3/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.8720 - accuracy: 0.3727 - val_loss: 1.9975 - val_accuracy: 0.3506
# Epoch 4/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.8643 - accuracy: 0.3768 - val_loss: 1.9905 - val_accuracy: 0.3636
# Epoch 5/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.8448 - accuracy: 0.3837 - val_loss: 2.1634 - val_accuracy: 0.3256
# Epoch 6/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.8426 - accuracy: 0.3862 - val_loss: 1.9421 - val_accuracy: 0.3564
# Epoch 7/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.8333 - accuracy: 0.3850 - val_loss: 2.1771 - val_accuracy: 0.3390
# Epoch 8/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.8320 - accuracy: 0.3916 - val_loss: 2.2691 - val_accuracy: 0.3066
# Epoch 9/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.8217 - accuracy: 0.3946 - val_loss: 2.0095 - val_accuracy: 0.3476
# Epoch 10/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.8158 - accuracy: 0.3903 - val_loss: 2.0202 - val_accuracy: 0.3465
# Epoch 11/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.8078 - accuracy: 0.3958 - val_loss: 1.9918 - val_accuracy: 0.3641
# Epoch 12/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.8192 - accuracy: 0.3944 - val_loss: 2.0584 - val_accuracy: 0.3521
# Epoch 13/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.7999 - accuracy: 0.4002 - val_loss: 2.2446 - val_accuracy: 0.3214
# Epoch 14/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.8066 - accuracy: 0.3960 - val_loss: 1.9299 - val_accuracy: 0.3543
# Epoch 15/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.8054 - accuracy: 0.3976 - val_loss: 1.9153 - val_accuracy: 0.3644
# Epoch 16/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.8042 - accuracy: 0.4011 - val_loss: 2.1174 - val_accuracy: 0.3223
# Epoch 17/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.7903 - accuracy: 0.4011 - val_loss: 2.4061 - val_accuracy: 0.3037
# Epoch 18/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.7835 - accuracy: 0.4058 - val_loss: 1.9514 - val_accuracy: 0.3433
# Epoch 19/30
#  202/1563 [==>...........................] - ETA: 3s - loss: 1.6852 - accuracy: 0.4362
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-cf9db4ee38e6> in <module>
# ----> 1 history_one_layer=one_layer_model.fit(x=X_train_vector,
#       2                                       y=y_train_onehot,
#       3                                       validation_data=(X_test_vector, y_test_onehot),
#       4                                       epochs=30)  # starts training
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1130                 _r=1):
#    1131               callbacks.on_train_batch_begin(step)
# -> 1132               tmp_logs = self.train_function(iterator)
#    1133               if data_handler.should_sync:
#    1134                 context.async_wait()
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     782     tracing_count = self.experimental_get_tracing_count()
#     783     with trace.Trace(self._name) as tm:
# --> 784       result = self._call(*args, **kwds)
#     785       compiler = "xla" if self._jit_compile else "nonXla"
#     786       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     809       # In this case we have created variables on the first call, so we run the
#     810       # defunned version which is guaranteed to never create variables.
# --> 811       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     812     elif self._stateful_fn is not None:
#     813       # Release the lock early so that multiple threads can perform the call
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2969       (graph_function,
#    2970        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2971     return graph_function._call_flat(
#    2972         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2973
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1945         and executing_eagerly):
#    1946       # No tape is watching; skip to running the function.
# -> 1947       return self._build_call_outputs(self._inference_function.call(
#    1948           ctx, args, cancellation_manager=cancellation_manager))
#    1949     forward_backward = self._select_forward_and_backward_functions(
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     554       with _InterpolateFunctionError(self):
#     555         if cancellation_manager is None:
# --> 556           outputs = execute.execute(
#     557               str(self.signature.name),
#     558               num_outputs=self._num_outputs,
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# We can also plot the the training process. Think a bit about what you are seeing here (you will also need to write about it for the documentation).

# %%
plot_history(history_one_layer)

# %% [markdown]
# We can also have a look at some predictions of our model of the test set. The function `plot_predictions(data, model_name, class_name=None)` plots predictions of of random images of the test set with our model. The input data should be X_test preprocessed as the model expects it. By specifying the optional parameter class_name, only correct predictions, false positives and false negatives of this class will be plotted. Feel free to change the parameters below. In the image below you can see an example output of the function with the `class_name='horse'` for a different model.
#
# ![alt text](https://owncloud.tuwien.ac.at/index.php/apps/files_sharing/ajax/publicpreview.php?x=1680&y=730&a=true&file=horse_prediction_mlpreg.png&t=0w2rKhrCgTDlMmb&scalingup=0)

# %%
plot_predictions(X_test_vector, one_layer_model)
# Out:
# Number of correct recognized images is 2068
# Number of wrong recognized images is 2288

# %%
plot_predictions(X_test_vector, one_layer_model, class_name='ship')
# Out:
# Number of correct recognized ship images is 504
# Number of images recognized as ship but are not of that class is 571
# Number of images not recognized as ship but actually are of that class is 147

# %% [markdown]
# ## Multilayer Perceptron (1 Point)
# The last model with only one layer reached appr. 30% of validation accuracy. It is already better than random guessing but not really satisfactory. Now it's time to add the "Deep" to Deep Learning. Create a model with multiple dense layers (a multilayer perceptron) with ReLu activation in the hidden layers and train it again for about 30 Epochs. The exact structure of the model is up to you, a good starting point is a layer with 256 units, followed by another layer with 128 units and followed by the output layer. This model should reach around 50% of validation accuracy. Training time is dependent on your model but should be below 20s per epoch.

# %%
########## Fix This Part ##########

# input layer
mlp_inputs = layers.Input(shape=X_train_vector.shape[1])

# layer 1
mlp_l1 = layers.Dense(units=256, activation="relu")(mlp_inputs)

# layer 2
mlp_l2 = layers.Dense(units=128, activation="relu")(mlp_l1)

# output layer
mlp_predictions = layers.Dense(units=10, activation="softmax")(mlp_l2)


###################################


mlp_model = Model(inputs = mlp_inputs, outputs = mlp_predictions)
mlp_model.compile(optimizer = 'sgd',
              loss='categorical_crossentropy', # We now use the built-in categorical_crossentropy loss
              metrics=['accuracy'])
history_mlp=mlp_model.fit(x = X_train_vector, 
                          y = y_train_onehot, 
                          validation_data = (X_test_vector, y_test_onehot), 
                          epochs = 30)  # starts training
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.6937 - accuracy: 0.4062 - val_loss: 1.5536 - val_accuracy: 0.4515
# Epoch 2/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.4602 - accuracy: 0.4886 - val_loss: 1.4563 - val_accuracy: 0.4841
# Epoch 3/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.3516 - accuracy: 0.5271 - val_loss: 1.4295 - val_accuracy: 0.5020
# Epoch 4/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.2681 - accuracy: 0.5593 - val_loss: 1.4117 - val_accuracy: 0.5043
# Epoch 5/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.2014 - accuracy: 0.5831 - val_loss: 1.4102 - val_accuracy: 0.5054
# Epoch 6/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.1388 - accuracy: 0.6071 - val_loss: 1.4013 - val_accuracy: 0.5152
# Epoch 7/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.0839 - accuracy: 0.6285 - val_loss: 1.4067 - val_accuracy: 0.5138
# Epoch 8/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.0354 - accuracy: 0.6416 - val_loss: 1.4026 - val_accuracy: 0.5234
# Epoch 9/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.9843 - accuracy: 0.6641 - val_loss: 1.4156 - val_accuracy: 0.5200
# Epoch 10/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.9397 - accuracy: 0.6765 - val_loss: 1.4399 - val_accuracy: 0.5163
# Epoch 11/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.8963 - accuracy: 0.6925 - val_loss: 1.4577 - val_accuracy: 0.5169
# Epoch 12/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.8518 - accuracy: 0.7077 - val_loss: 1.4894 - val_accuracy: 0.5225
# Epoch 13/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.8123 - accuracy: 0.7194 - val_loss: 1.5369 - val_accuracy: 0.5120
# Epoch 14/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.7742 - accuracy: 0.7342 - val_loss: 1.5581 - val_accuracy: 0.5164
# Epoch 15/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.7361 - accuracy: 0.7486 - val_loss: 1.5796 - val_accuracy: 0.5184
# Epoch 16/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.7012 - accuracy: 0.7591 - val_loss: 1.6941 - val_accuracy: 0.5029
# Epoch 17/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.6684 - accuracy: 0.7700 - val_loss: 1.6805 - val_accuracy: 0.5161
# Epoch 18/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.6310 - accuracy: 0.7849 - val_loss: 1.7094 - val_accuracy: 0.5099
# Epoch 19/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.6016 - accuracy: 0.7940 - val_loss: 1.7962 - val_accuracy: 0.4978
# Epoch 20/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5696 - accuracy: 0.8061 - val_loss: 1.7805 - val_accuracy: 0.5100
# Epoch 21/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5392 - accuracy: 0.8180 - val_loss: 1.8106 - val_accuracy: 0.5086
# Epoch 22/30
# 1563/1563 [==============================] - 5s 3ms/step - loss: 0.5102 - accuracy: 0.8264 - val_loss: 1.8700 - val_accuracy: 0.5127
# Epoch 23/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.4826 - accuracy: 0.8365 - val_loss: 1.9080 - val_accuracy: 0.5112
# Epoch 24/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.4572 - accuracy: 0.8451 - val_loss: 1.9296 - val_accuracy: 0.5134
# Epoch 25/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.4388 - accuracy: 0.8515 - val_loss: 2.0269 - val_accuracy: 0.4999
# Epoch 26/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.4136 - accuracy: 0.8613 - val_loss: 2.1120 - val_accuracy: 0.5006
# Epoch 27/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.3862 - accuracy: 0.8711 - val_loss: 2.1601 - val_accuracy: 0.5066
# Epoch 28/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.3682 - accuracy: 0.8765 - val_loss: 2.1402 - val_accuracy: 0.5112
# Epoch 29/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.3458 - accuracy: 0.8837 - val_loss: 2.2460 - val_accuracy: 0.4958
# Epoch 30/30
# 1563/1563 [==============================] - 4s 3ms/step - loss: 0.3281 - accuracy: 0.8920 - val_loss: 2.2738 - val_accuracy: 0.5043

# %% [markdown]
# Time again to plot the training. You should now see the effect of overfitting.

# %%
plot_history(history_mlp)

# %% [markdown]
# ## MLP with Regularization (1 Point)
# To counter the problem of overfitting, you should add measures for regularization. Create a new model based on your MLP from the last point which includes at least one regularization technique. It should improve the validation accuracy slightly.

# %%
########## Fix This Part ##########

p_dropout = 0.2
l2_reg = 0.003

# input layer
mlpreg_inputs = layers.Input(shape=X_train_vector.shape[1])

# layer 1 with dropout and L2 regularisation
mlpreg_dropout1 = layers.Dropout(p_dropout)(mlpreg_inputs)
mlpreg_l1 = layers.Dense(units=256, activation="relu", kernel_regularizer=regularizers.l2(l2_reg))(mlpreg_dropout1)

# layer 2 with dropout and L2 regularisation
mlpreg_dropout2 = layers.Dropout(p_dropout)(mlpreg_l1)
mlpreg_l2 = layers.Dense(units=128, activation="relu", kernel_regularizer=regularizers.l2(l2_reg))(mlpreg_dropout2)

# output layer
mlpreg_predictions = layers.Dense(units=10, activation="softmax")(mlpreg_l2)

###################################

mlpreg_model = Model(inputs = mlpreg_inputs, outputs = mlpreg_predictions)

# We save the weights here before training to reset them in the experiments part later
mlpreg_model.save_weights('mlpreg_model_weights.h5') 

mlpreg_model.compile(optimizer = 'sgd',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])
mlpreg_model.summary()
history_mlpreg = mlpreg_model.fit(x = X_train_vector, 
                          y = y_train_onehot, 
                          validation_data = (X_test_vector, y_test_onehot), 
                          epochs = 30)  # starts training
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 3072)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               786688
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 820,874
# Trainable params: 820,874
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 3.5687 - accuracy: 0.3577 - val_loss: 3.1736 - val_accuracy: 0.4476
# Epoch 2/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 3.0717 - accuracy: 0.4314 - val_loss: 2.8377 - val_accuracy: 0.4659
# Epoch 3/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.7558 - accuracy: 0.4608 - val_loss: 2.5714 - val_accuracy: 0.4891
# Epoch 4/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.5054 - accuracy: 0.4797 - val_loss: 2.3661 - val_accuracy: 0.4976
# Epoch 5/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3038 - accuracy: 0.4951 - val_loss: 2.2006 - val_accuracy: 0.5096
# Epoch 6/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.1364 - accuracy: 0.5083 - val_loss: 2.0603 - val_accuracy: 0.5145
# Epoch 7/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.0050 - accuracy: 0.5163 - val_loss: 1.9445 - val_accuracy: 0.5249
# Epoch 8/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.8914 - accuracy: 0.5299 - val_loss: 1.8717 - val_accuracy: 0.5196
# Epoch 9/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.7958 - accuracy: 0.5376 - val_loss: 1.7868 - val_accuracy: 0.5299
# Epoch 10/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.7214 - accuracy: 0.5423 - val_loss: 1.7174 - val_accuracy: 0.5314
# Epoch 11/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.6590 - accuracy: 0.5483 - val_loss: 1.6612 - val_accuracy: 0.5361
# Epoch 12/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.6054 - accuracy: 0.5544 - val_loss: 1.6350 - val_accuracy: 0.5374
# Epoch 13/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.5553 - accuracy: 0.5618 - val_loss: 1.5896 - val_accuracy: 0.5422
# Epoch 14/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.5193 - accuracy: 0.5648 - val_loss: 1.5739 - val_accuracy: 0.5418
# Epoch 15/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.4942 - accuracy: 0.5672 - val_loss: 1.5525 - val_accuracy: 0.5424
# Epoch 16/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.4650 - accuracy: 0.5739 - val_loss: 1.5393 - val_accuracy: 0.5391
# Epoch 17/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.4414 - accuracy: 0.5751 - val_loss: 1.5482 - val_accuracy: 0.5375
# Epoch 18/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.4225 - accuracy: 0.5798 - val_loss: 1.5245 - val_accuracy: 0.5383
# Epoch 19/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.4098 - accuracy: 0.5831 - val_loss: 1.5125 - val_accuracy: 0.5401
# Epoch 20/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.3954 - accuracy: 0.5868 - val_loss: 1.4964 - val_accuracy: 0.5494
# Epoch 21/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3876 - accuracy: 0.5868 - val_loss: 1.5024 - val_accuracy: 0.5452
# Epoch 22/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.3719 - accuracy: 0.5914 - val_loss: 1.4863 - val_accuracy: 0.5435
# Epoch 23/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.3659 - accuracy: 0.5935 - val_loss: 1.4855 - val_accuracy: 0.5480
# Epoch 24/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3591 - accuracy: 0.5968 - val_loss: 1.4616 - val_accuracy: 0.5592
# Epoch 25/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.3553 - accuracy: 0.5968 - val_loss: 1.4966 - val_accuracy: 0.5442
# Epoch 26/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.3413 - accuracy: 0.6007 - val_loss: 1.4860 - val_accuracy: 0.5474
# Epoch 27/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.3404 - accuracy: 0.6016 - val_loss: 1.4696 - val_accuracy: 0.5484
# Epoch 28/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.3366 - accuracy: 0.6032 - val_loss: 1.4668 - val_accuracy: 0.5533
# Epoch 29/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.3354 - accuracy: 0.6051 - val_loss: 1.4499 - val_accuracy: 0.5623
# Epoch 30/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.3249 - accuracy: 0.6093 - val_loss: 1.4736 - val_accuracy: 0.5509

# %% [markdown]
# Let's plot the training process again. If the overfitting is not solved, add additional regularization techniques.

# %%
plot_history(history_mlpreg)

# %% [markdown]
# We can again plot some predictions.

# %%
plot_predictions(X_test_vector, mlpreg_model, class_name=None)
# Out:
# Number of correct recognized images is 3841
# Number of wrong recognized images is 1512

# %% [markdown]
# ## Convolutional Neural Network (2 Points)
# When converting our images to vectors, all spatial information is lost. A convolutional neural network takes matrices (tensors to be more precise) as input and computes features which make use of spatial information. In this exercise implement a neural network as specified in the image below. Add regularization techniques until you reach at least 75% of validation accuracy with a training time of below 30s per epoch.
#
# Notes: 3x3 Conv X means a Conv2D layer with kernel 3x3 and X units.
# Maxpool /2 means a MaxPool layer with kernel=(2,2) and stride=2.
#
#
# ![Network Architecture](https://owncloud.tuwien.ac.at/index.php/apps/files_sharing/ajax/publicpreview.php?x=3360&y=1178&a=true&file=CNN-architecture.png&t=Ms797G0SEXgeZZe&scalingup=0)

# %%
X_train_normalized, X_test_normalized = normalize_images(X_train,X_test)

########## Fix This Part ##########

p_dropout = 0.2

cnn_inputs = layers.Input(shape=X_train_normalized.shape[1:])

cnn_conv1 = layers.Conv2D(32, 3, activation="relu")(cnn_inputs)
cnn_pool1 = layers.MaxPool2D((2,2), strides=(2,2))(cnn_conv1)

cnn_dropout1 = layers.Dropout(p_dropout)(cnn_pool1)

cnn_conv2 = layers.Conv2D(64, 3, activation="relu")(cnn_dropout1)
cnn_pool2 = layers.MaxPool2D((2,2), strides=(2,2))(cnn_conv2)

cnn_dropout2 = layers.Dropout(p_dropout)(cnn_pool2)

cnn_conv3 = layers.Conv2D(128, 3, activation="relu")(cnn_dropout2)

cnn_avg = layers.GlobalAveragePooling2D()(cnn_conv3)
cnn_dropout3 = layers.Dropout(p_dropout)(cnn_avg)
cnn_dense = layers.Dense(units=512, activation="relu")(cnn_dropout3)

cnn_predictions = layers.Dense(units=10, activation="softmax")(cnn_dense)

###################################

cnn_model = Model(inputs=cnn_inputs, outputs=cnn_predictions)

# We use the Adam optimizer here which uses more complex methods than our standard SGD
cnn_model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

cnn_model.summary()
history_cnn=cnn_model.fit(x=X_train_normalized, 
                          y=y_train_onehot, 
                          validation_data=(X_test_normalized, y_test_onehot), 
                          epochs=30)  # starts training
# Out:
# mean before 120.70756512369792
# std before 64.1500758911213
# normalised
# mean after 5.1523230126804264e-17
# std after 0.9999999981401643
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 128)         73856
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               66048
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 164,426
# Trainable params: 164,426
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.5563 - accuracy: 0.4236 - val_loss: 1.2287 - val_accuracy: 0.5705
# Epoch 2/30
# 1563/1563 [==============================] - 12s 7ms/step - loss: 1.1922 - accuracy: 0.5737 - val_loss: 1.0372 - val_accuracy: 0.6359
# Epoch 3/30
# 1563/1563 [==============================] - 12s 7ms/step - loss: 1.0417 - accuracy: 0.6294 - val_loss: 0.9378 - val_accuracy: 0.6715
# Epoch 4/30
# 1563/1563 [==============================] - 12s 7ms/step - loss: 0.9596 - accuracy: 0.6614 - val_loss: 0.8589 - val_accuracy: 0.7016
# Epoch 5/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.8992 - accuracy: 0.6810 - val_loss: 0.8133 - val_accuracy: 0.7145
# Epoch 6/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.8524 - accuracy: 0.6999 - val_loss: 0.7757 - val_accuracy: 0.7305
# Epoch 7/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.8161 - accuracy: 0.7129 - val_loss: 0.7566 - val_accuracy: 0.7336
# Epoch 8/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.7925 - accuracy: 0.7193 - val_loss: 0.7292 - val_accuracy: 0.7472
# Epoch 9/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.7679 - accuracy: 0.7295 - val_loss: 0.7004 - val_accuracy: 0.7563
# Epoch 10/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.7436 - accuracy: 0.7380 - val_loss: 0.6856 - val_accuracy: 0.7617
# Epoch 11/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.7294 - accuracy: 0.7439 - val_loss: 0.6829 - val_accuracy: 0.7609
# Epoch 12/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.7056 - accuracy: 0.7525 - val_loss: 0.6879 - val_accuracy: 0.7553
# Epoch 13/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.7031 - accuracy: 0.7500 - val_loss: 0.6567 - val_accuracy: 0.7721
# Epoch 14/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.6880 - accuracy: 0.7569 - val_loss: 0.6876 - val_accuracy: 0.7620
# Epoch 15/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.6776 - accuracy: 0.7601 - val_loss: 0.6694 - val_accuracy: 0.7675
# Epoch 16/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.6686 - accuracy: 0.7650 - val_loss: 0.6776 - val_accuracy: 0.7652
# Epoch 17/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.6558 - accuracy: 0.7711 - val_loss: 0.6466 - val_accuracy: 0.7757
# Epoch 18/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.6417 - accuracy: 0.7743 - val_loss: 0.6533 - val_accuracy: 0.7737
# Epoch 19/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.6399 - accuracy: 0.7721 - val_loss: 0.6977 - val_accuracy: 0.7576
# Epoch 20/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.6236 - accuracy: 0.7794 - val_loss: 0.6327 - val_accuracy: 0.7812
# Epoch 21/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.6195 - accuracy: 0.7807 - val_loss: 0.6927 - val_accuracy: 0.7595
# Epoch 22/30
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.6216 - accuracy: 0.7810 - val_loss: 0.6128 - val_accuracy: 0.7874
# Epoch 23/30
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.6063 - accuracy: 0.7851 - val_loss: 0.6544 - val_accuracy: 0.7772
# Epoch 24/30
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.6056 - accuracy: 0.7863 - val_loss: 0.6192 - val_accuracy: 0.7874
# Epoch 25/30
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5974 - accuracy: 0.7892 - val_loss: 0.6259 - val_accuracy: 0.7862
# Epoch 26/30
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5869 - accuracy: 0.7936 - val_loss: 0.6172 - val_accuracy: 0.7908
# Epoch 27/30
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5881 - accuracy: 0.7915 - val_loss: 0.6191 - val_accuracy: 0.7890
# Epoch 28/30
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5848 - accuracy: 0.7947 - val_loss: 0.6256 - val_accuracy: 0.7861
# Epoch 29/30
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5813 - accuracy: 0.7957 - val_loss: 0.6310 - val_accuracy: 0.7835
# Epoch 30/30
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5753 - accuracy: 0.7943 - val_loss: 0.6285 - val_accuracy: 0.7843

# %% [markdown]
# Plot the training again.

# %%
plot_history(history_cnn)

# %% [markdown]
# We can again plot some predictions.

# %%
plot_predictions(X_test_normalized, cnn_model, class_name=None)
# Out:
# Number of correct recognized images is 7301
# Number of wrong recognized images is 1352

# %% [markdown]
# ##Finetuning (2 Points)
# In the next step we want to use a model which is already pretrained on a large dataset (Imagenet) and finetune it for the CIFAR10 dataset. Keras already provides us with multiple pretrained models (see https://keras.io/applications/). Your task is to take the ResNet50 model and **only** retrain the last layer. You should upsample the images first because ResNet is trained on Images with the resolution of (224, 224). However training with this resolution takes very long with not that much gain. A resolution of (128, 128) is a good compromise between accuracy and training time. You can use the `UpSampling2D` layer of Keras. You should also preprocess the images the same way as ResNet using the function `preprocess_input` from the ResNet50 library. This approach should get you to over 80% of validation accuracy. Training time will take much longer here (~120 seconds per epoch), so we will only train for 5 epochs.

# %%
from tensorflow.keras.applications.resnet import ResNet50, preprocess_input

########## Fix This Part ##########

p_dropout = 0.2

# process inputs
X_train_resnet = preprocess_input(X_train)
X_test_resnet = preprocess_input(X_test)

resnet_input = layers.Input(shape=X_train_resnet.shape[1:])
resnet_scaled = layers.UpSampling2D(size=(4,4))(resnet_input)
# set up resnet, use pretrained weights, enable pooling, discard last layer
resnet = ResNet50(include_top=False, weights="imagenet", pooling="avg", input_shape= (128, 128, 3))
resnet.trainable = False

resnet_out = resnet(resnet_scaled)
# fully connected layer (replacing the last layer in ResNet50)

resnet_dense = layers.Dense(units=1000, activation="relu")(resnet_out)
resnet_dropout2 = layers.Dropout(p_dropout)(resnet_dense)
resnet_predictions = layers.Dense(units=10, activation="softmax")(resnet_dropout2)

###################################

resnet_model = Model(inputs=resnet_input, outputs=resnet_predictions)
resnet_model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

resnet_model.summary()
history_resnet=resnet_model.fit(x=X_train_resnet, 
                          y=y_train_onehot, 
                          validation_data=(X_test_resnet, y_test_onehot),
                          epochs=5)  # starts training
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 128, 128, 3)       0
# _________________________________________________________________
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# dense_2 (Dense)              (None, 1000)              2049000
# _________________________________________________________________
# dropout (Dropout)            (None, 1000)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 25,646,722
# Trainable params: 2,059,010
# Non-trainable params: 23,587,712
# _________________________________________________________________
# Epoch 1/5
# 1563/1563 [==============================] - 81s 46ms/step - loss: 0.9372 - accuracy: 0.7134 - val_loss: 0.5898 - val_accuracy: 0.7932
# Epoch 2/5
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.5344 - accuracy: 0.8137 - val_loss: 0.5585 - val_accuracy: 0.8113
# Epoch 3/5
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.4626 - accuracy: 0.8374 - val_loss: 0.5450 - val_accuracy: 0.8158
# Epoch 4/5
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.4176 - accuracy: 0.8546 - val_loss: 0.5179 - val_accuracy: 0.8297
# Epoch 5/5
#  169/1563 [==>...........................] - ETA: 53s - loss: 0.3530 - accuracy: 0.8761

# %%
plot_history(history_resnet)

# %% [markdown]
# # Experiments
# Here you can add code that you need for your documentation. Feel free to play around in this section with the models, your own images, create new models, data augmentation, different datasets, ...

# %% [markdown]
# **Experiment 2.1**

# %%
# Create an optimizer and then reload weights we saved earlier.
my_sgd = optimizers.SGD(learning_rate=0.1)
mlpreg_model.load_weights('mlpreg_model_weights.h5')

mlpreg_model.compile(optimizer = my_sgd,
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])
mlpreg_model.summary()
history_mlpreg_a = mlpreg_model.fit(x = X_train_vector, 
                          y = y_train_onehot, 
                          validation_data = (X_test_vector, y_test_onehot), 
                          epochs = 30)  # starts training
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 3072)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               786688
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 820,874
# Trainable params: 820,874
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.7775 - accuracy: 0.3651 - val_loss: 2.0983 - val_accuracy: 0.4196
# Epoch 2/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.9818 - accuracy: 0.4136 - val_loss: 1.9439 - val_accuracy: 0.4060
# Epoch 3/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8711 - accuracy: 0.4238 - val_loss: 1.8412 - val_accuracy: 0.4231
# Epoch 4/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8534 - accuracy: 0.4268 - val_loss: 1.8168 - val_accuracy: 0.4371
# Epoch 5/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8492 - accuracy: 0.4295 - val_loss: 1.8631 - val_accuracy: 0.4266
# Epoch 6/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.8500 - accuracy: 0.4319 - val_loss: 1.8569 - val_accuracy: 0.4365
# Epoch 7/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.8493 - accuracy: 0.4323 - val_loss: 1.9314 - val_accuracy: 0.3962
# Epoch 8/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.8429 - accuracy: 0.4347 - val_loss: 1.8370 - val_accuracy: 0.4340
# Epoch 9/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8388 - accuracy: 0.4368 - val_loss: 1.8961 - val_accuracy: 0.4234
# Epoch 10/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8347 - accuracy: 0.4409 - val_loss: 2.0896 - val_accuracy: 0.3874
# Epoch 11/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8335 - accuracy: 0.4433 - val_loss: 1.8057 - val_accuracy: 0.4474
# Epoch 12/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8357 - accuracy: 0.4413 - val_loss: 1.8828 - val_accuracy: 0.4175
# Epoch 13/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8287 - accuracy: 0.4442 - val_loss: 1.8930 - val_accuracy: 0.4248
# Epoch 14/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8326 - accuracy: 0.4440 - val_loss: 1.8919 - val_accuracy: 0.4192
# Epoch 15/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8330 - accuracy: 0.4413 - val_loss: 1.8440 - val_accuracy: 0.4312
# Epoch 16/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8258 - accuracy: 0.4435 - val_loss: 1.9058 - val_accuracy: 0.4248
# Epoch 17/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8269 - accuracy: 0.4460 - val_loss: 1.8338 - val_accuracy: 0.4436
# Epoch 18/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8253 - accuracy: 0.4477 - val_loss: 1.7799 - val_accuracy: 0.4651
# Epoch 19/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8224 - accuracy: 0.4496 - val_loss: 1.7895 - val_accuracy: 0.4597
# Epoch 20/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8252 - accuracy: 0.4485 - val_loss: 1.8305 - val_accuracy: 0.4520
# Epoch 21/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.8269 - accuracy: 0.4467 - val_loss: 1.8166 - val_accuracy: 0.4566
# Epoch 22/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.8256 - accuracy: 0.4484 - val_loss: 1.8270 - val_accuracy: 0.4497
# Epoch 23/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8259 - accuracy: 0.4457 - val_loss: 1.9451 - val_accuracy: 0.4072
# Epoch 24/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8239 - accuracy: 0.4485 - val_loss: 1.8045 - val_accuracy: 0.4509
# Epoch 25/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8152 - accuracy: 0.4499 - val_loss: 1.8651 - val_accuracy: 0.4309
# Epoch 26/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8199 - accuracy: 0.4510 - val_loss: 1.8055 - val_accuracy: 0.4598
# Epoch 27/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8184 - accuracy: 0.4561 - val_loss: 1.8366 - val_accuracy: 0.4495
# Epoch 28/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8210 - accuracy: 0.4525 - val_loss: 1.8761 - val_accuracy: 0.4344
# Epoch 29/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8157 - accuracy: 0.4516 - val_loss: 1.7931 - val_accuracy: 0.4599
# Epoch 30/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8206 - accuracy: 0.4507 - val_loss: 1.8379 - val_accuracy: 0.4502

# %%
plot_history(history_mlpreg_a)

# %% [markdown]
# **Experiment 2.2**

# %%
my_sgd = optimizers.SGD(learning_rate=0.001)
mlpreg_model.load_weights('mlpreg_model_weights.h5')

mlpreg_model.compile(optimizer = my_sgd,
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])
mlpreg_model.summary()
history_mlpreg_b = mlpreg_model.fit(x = X_train_vector, 
                          y = y_train_onehot, 
                          validation_data = (X_test_vector, y_test_onehot), 
                          epochs = 30)  # starts training
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 3072)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               786688
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 820,874
# Trainable params: 820,874
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 4.0277 - accuracy: 0.2531 - val_loss: 3.7061 - val_accuracy: 0.3584
# Epoch 2/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 3.7452 - accuracy: 0.3328 - val_loss: 3.5703 - val_accuracy: 0.3994
# Epoch 3/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 3.6270 - accuracy: 0.3613 - val_loss: 3.4781 - val_accuracy: 0.4172
# Epoch 4/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 3.5361 - accuracy: 0.3841 - val_loss: 3.4102 - val_accuracy: 0.4289
# Epoch 5/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 3.4682 - accuracy: 0.3992 - val_loss: 3.3462 - val_accuracy: 0.4397
# Epoch 6/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 3.4060 - accuracy: 0.4080 - val_loss: 3.2927 - val_accuracy: 0.4475
# Epoch 7/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 3.3499 - accuracy: 0.4184 - val_loss: 3.2437 - val_accuracy: 0.4530
# Epoch 8/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 3.3006 - accuracy: 0.4252 - val_loss: 3.1979 - val_accuracy: 0.4587
# Epoch 9/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 3.2509 - accuracy: 0.4326 - val_loss: 3.1511 - val_accuracy: 0.4643
# Epoch 10/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 3.2055 - accuracy: 0.4354 - val_loss: 3.1097 - val_accuracy: 0.4692
# Epoch 11/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 3.1595 - accuracy: 0.4409 - val_loss: 3.0683 - val_accuracy: 0.4730
# Epoch 12/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 3.1112 - accuracy: 0.4472 - val_loss: 3.0304 - val_accuracy: 0.4751
# Epoch 13/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 3.0713 - accuracy: 0.4515 - val_loss: 2.9918 - val_accuracy: 0.4762
# Epoch 14/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 3.0344 - accuracy: 0.4556 - val_loss: 2.9547 - val_accuracy: 0.4808
# Epoch 15/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 2.9915 - accuracy: 0.4608 - val_loss: 2.9200 - val_accuracy: 0.4823
# Epoch 16/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.9560 - accuracy: 0.4651 - val_loss: 2.8863 - val_accuracy: 0.4843
# Epoch 17/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.9192 - accuracy: 0.4689 - val_loss: 2.8537 - val_accuracy: 0.4858
# Epoch 18/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.8847 - accuracy: 0.4722 - val_loss: 2.8212 - val_accuracy: 0.4905
# Epoch 19/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.8495 - accuracy: 0.4764 - val_loss: 2.7889 - val_accuracy: 0.4924
# Epoch 20/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 2.8160 - accuracy: 0.4796 - val_loss: 2.7598 - val_accuracy: 0.4942
# Epoch 21/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.7814 - accuracy: 0.4821 - val_loss: 2.7300 - val_accuracy: 0.4983
# Epoch 22/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.7507 - accuracy: 0.4857 - val_loss: 2.7016 - val_accuracy: 0.4958
# Epoch 23/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.7210 - accuracy: 0.4878 - val_loss: 2.6714 - val_accuracy: 0.5018
# Epoch 24/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.6859 - accuracy: 0.4939 - val_loss: 2.6441 - val_accuracy: 0.5042
# Epoch 25/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.6627 - accuracy: 0.4946 - val_loss: 2.6176 - val_accuracy: 0.5033
# Epoch 26/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 2.6309 - accuracy: 0.4978 - val_loss: 2.5907 - val_accuracy: 0.5033
# Epoch 27/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.6038 - accuracy: 0.5017 - val_loss: 2.5644 - val_accuracy: 0.5110
# Epoch 28/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.5731 - accuracy: 0.5021 - val_loss: 2.5406 - val_accuracy: 0.5104
# Epoch 29/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.5481 - accuracy: 0.5050 - val_loss: 2.5174 - val_accuracy: 0.5102
# Epoch 30/30
# 1563/1563 [==============================] - 7s 4ms/step - loss: 2.5200 - accuracy: 0.5072 - val_loss: 2.4922 - val_accuracy: 0.5089

# %%
plot_history(history_mlpreg_b)

# %% [markdown]
# **Experiment 2.3**

# %%
mlpreg_model.load_weights('mlpreg_model_weights.h5')

mlpreg_model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])
mlpreg_model.summary()
history_mlpreg_c = mlpreg_model.fit(x = X_train_vector, 
                          y = y_train_onehot, 
                          validation_data = (X_test_vector, y_test_onehot), 
                          epochs = 30)  # starts training
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 3072)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               786688
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 820,874
# Trainable params: 820,874
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.7174 - accuracy: 0.3559 - val_loss: 2.0109 - val_accuracy: 0.4114
# Epoch 2/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.0152 - accuracy: 0.3939 - val_loss: 1.9060 - val_accuracy: 0.4242
# Epoch 3/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.9717 - accuracy: 0.3950 - val_loss: 1.9327 - val_accuracy: 0.4120
# Epoch 4/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.9564 - accuracy: 0.3952 - val_loss: 1.9235 - val_accuracy: 0.4020
# Epoch 5/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.9436 - accuracy: 0.3973 - val_loss: 1.8959 - val_accuracy: 0.4217
# Epoch 6/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.9351 - accuracy: 0.3979 - val_loss: 1.8755 - val_accuracy: 0.4225
# Epoch 7/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.9245 - accuracy: 0.4026 - val_loss: 1.8411 - val_accuracy: 0.4322
# Epoch 8/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.9179 - accuracy: 0.4041 - val_loss: 1.8746 - val_accuracy: 0.4220
# Epoch 9/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.9098 - accuracy: 0.4037 - val_loss: 1.8355 - val_accuracy: 0.4284
# Epoch 10/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8994 - accuracy: 0.4057 - val_loss: 1.8295 - val_accuracy: 0.4284
# Epoch 11/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.8937 - accuracy: 0.4100 - val_loss: 1.8078 - val_accuracy: 0.4441
# Epoch 12/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8843 - accuracy: 0.4089 - val_loss: 1.7861 - val_accuracy: 0.4407
# Epoch 13/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.8756 - accuracy: 0.4105 - val_loss: 1.8361 - val_accuracy: 0.4169
# Epoch 14/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8688 - accuracy: 0.4117 - val_loss: 1.8002 - val_accuracy: 0.4327
# Epoch 15/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8606 - accuracy: 0.4163 - val_loss: 1.8043 - val_accuracy: 0.4332
# Epoch 16/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8600 - accuracy: 0.4144 - val_loss: 1.7585 - val_accuracy: 0.4504
# Epoch 17/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8522 - accuracy: 0.4143 - val_loss: 1.7802 - val_accuracy: 0.4460
# Epoch 18/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8456 - accuracy: 0.4185 - val_loss: 1.7631 - val_accuracy: 0.4429
# Epoch 19/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8445 - accuracy: 0.4128 - val_loss: 1.7493 - val_accuracy: 0.4522
# Epoch 20/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8419 - accuracy: 0.4165 - val_loss: 1.7740 - val_accuracy: 0.4371
# Epoch 21/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8413 - accuracy: 0.4156 - val_loss: 1.7996 - val_accuracy: 0.4267
# Epoch 22/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8368 - accuracy: 0.4164 - val_loss: 1.7878 - val_accuracy: 0.4316
# Epoch 23/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8355 - accuracy: 0.4150 - val_loss: 1.7616 - val_accuracy: 0.4473
# Epoch 24/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8323 - accuracy: 0.4194 - val_loss: 1.7662 - val_accuracy: 0.4418
# Epoch 25/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8254 - accuracy: 0.4187 - val_loss: 1.7525 - val_accuracy: 0.4530
# Epoch 26/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8250 - accuracy: 0.4184 - val_loss: 1.7332 - val_accuracy: 0.4524
# Epoch 27/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.8224 - accuracy: 0.4188 - val_loss: 1.7388 - val_accuracy: 0.4499
# Epoch 28/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.8262 - accuracy: 0.4200 - val_loss: 1.7538 - val_accuracy: 0.4346
# Epoch 29/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8167 - accuracy: 0.4198 - val_loss: 1.7384 - val_accuracy: 0.4456
# Epoch 30/30
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8159 - accuracy: 0.4211 - val_loss: 1.7610 - val_accuracy: 0.4419

# %%
plot_history(history_mlpreg_c)

# %% [markdown]
# **Experiment 3.1**

# %%
test_im1 = load_image_link('https://www.zooroyal.de/magazin/wp-content/uploads/2019/02/Quarter-Horse_760x560.jpg')

plt.imshow(test_im1[0,...])
test_im1 = normalize_images(X_train, test_im1)[1]
vec_im1 = vectorize_images(test_im1)
# Out:
# mean before 120.70756512369792
# std before 64.1500758911213
# normalised
# mean after 5.1523230126804264e-17
# std after 0.9999999981401643
# reshaped to (1, 3072)

# %%
predict_image(mlpreg_model, vec_im1)
predict_image(cnn_model, test_im1)
# Out:
# [[0.0093709  0.0050631  0.11053835 0.04838231 0.42078203 0.0706372
#   0.04902057 0.27717894 0.00353522 0.00549136]]
# Top-5 Predictions:
#   Deer - 42.08 %
#   Horse - 27.72 %
#   Bird - 11.05 %
#   Dog - 7.06 %
#   Frog - 4.9 %
# [[8.0092985e-05 1.9232943e-06 5.5002850e-03 4.5974919e-04 7.4557549e-01
#   1.6318592e-03 1.9326116e-03 2.4479893e-01 1.1826059e-05 7.2908492e-06]]
# Top-5 Predictions:
#   Deer - 74.56 %
#   Horse - 24.48 %
#   Bird - 0.55 %
#   Frog - 0.19 %
#   Dog - 0.16 %

# %%
test_im2 = load_image_link('https://media.ehorses.de/grafiken/rassen/shire-horse.jpg')
plt.imshow(test_im2[0,...])
test_im2 = normalize_images(X_train, test_im2)[1]
vec_im2 = vectorize_images(test_im2)
# Out:
# mean before 120.70756512369792
# std before 64.1500758911213
# normalised
# mean after 5.1523230126804264e-17
# std after 0.9999999981401643
# reshaped to (1, 3072)

# %%
predict_image(mlpreg_model, vec_im2)
predict_image(cnn_model, test_im2)
# Out:
# [[0.03793757 0.01033912 0.14543739 0.14057457 0.16638795 0.18670957
#   0.01962958 0.26206347 0.00960261 0.02131812]]
# Top-5 Predictions:
#   Horse - 26.21 %
#   Dog - 18.67 %
#   Deer - 16.64 %
#   Bird - 14.54 %
#   Cat - 14.06 %
# [[3.7510992e-05 1.0928904e-07 1.3943807e-04 1.2049499e-04 3.0700438e-02
#   4.5501296e-03 2.5950899e-06 9.6444827e-01 8.8349459e-08 9.5089206e-07]]
# Top-5 Predictions:
#   Horse - 96.44 %
#   Deer - 3.07 %
#   Dog - 0.46 %
#   Bird - 0.01 %
#   Cat - 0.01 %

# %%
test_im3 = load_image_link('https://images.photowall.com/products/61294/red-horse-run.jpg?h=699&q=85')
plt.imshow(test_im3[0,...])
test_im3 = normalize_images(X_train, test_im3)[1]
vec_im3 = vectorize_images(test_im3)
# Out:
# mean before 120.70756512369792
# std before 64.1500758911213
# normalised
# mean after 5.1523230126804264e-17
# std after 0.9999999981401643
# reshaped to (1, 3072)

# %%
predict_image(mlpreg_model, vec_im3)
predict_image(cnn_model, test_im3)
# Out:
# [[0.04309899 0.01479681 0.11119739 0.04162042 0.19196689 0.06663374
#   0.00714857 0.49156517 0.00691903 0.02505296]]
# Top-5 Predictions:
#   Horse - 49.16 %
#   Deer - 19.2 %
#   Bird - 11.12 %
#   Dog - 6.66 %
#   Airplane - 4.31 %
# [[2.0038304e-07 1.2161044e-09 1.6141936e-04 1.0250247e-04 2.0538822e-02
#   2.9488637e-03 1.5791444e-07 9.7624785e-01 3.5164273e-08 6.5789685e-08]]
# Top-5 Predictions:
#   Horse - 97.62 %
#   Deer - 2.05 %
#   Dog - 0.29 %
#   Bird - 0.02 %
#   Cat - 0.01 %

# %% [markdown]
# **Experiment 3.2**

# %%
plot_predictions(X_test_vector, one_layer_model, class_name='horse')
# Out:
# Number of correct recognized horse images is 251
# Number of images recognized as horse but are not of that class is 173
# Number of images not recognized as horse but actually are of that class is 200

# %%
# If you want to mount your Google Drive to store weights or plots for example
# you can use the commands below. Check this link for more information:
# https://colab.research.google.com/notebooks/io.ipynb#scrollTo=u22w3BFiOveA
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
